# %%
 import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv("NBA_PLAYERS.csv")
print(df)
# Out:
#                      Name  Debut  Final               Position  Height  \
# 0          Alaa Abdelnaby   1991   1995  ['Forward', 'Center']      82
# 1         Zaid Abdul-Aziz   1969   1978  ['Center', 'Forward']      81
# 2     Kareem Abdul-Jabbar   1970   1989             ['Center']      86
# 3      Mahmoud Abdul-Rauf   1991   2001              ['Guard']      73
# 4       Tariq Abdul-Wahad   1998   2003            ['Forward']      78
# ...                   ...    ...    ...                    ...     ...
# 5308           Ante Žižić   2018   2020  ['Forward', 'Center']      82
# 5309             Jim Zoet   1983   1983             ['Center']      85
# 5310            Bill Zopf   1971   1971              ['Guard']      73
# 5311          Ivica Zubac   2017   2025             ['Center']      84
# 5312           Matt Zunic   1949   1949   ['Guard', 'Forward']      75
#
#       Weight           Birthday                           School    HOF  \
# ...

# %%
mean_value = np.mean(df["Height"])
plt.figure(figsize=(11, 5))
plt.hist(df["Height"], bins=15 ,color='blue', edgecolor='black' , alpha=0.5, label='Tinggi Badan')
plt.axvline(mean_value , color='red',linestyle='--', linewidth='3' , label=f'Mean: {mean_value:.2f}')
plt.title('rata rata tinggi pemain')
plt.xlabel('Tinggi Badan')
plt.ylabel('Banyak Pemain')
plt.legend()
plt.show()

# %%
x = df[["Height"]]
y = df["PTS"]

model = LinearRegression()
model.fit(x, y)

y_pred = model.predict(x)

plt.figure(figsize=(8, 6))
plt.scatter(df['Height'], y_pred, color='red', label='Titik Nilai')
plt.plot(df['Height'],y_pred, color='blue', label='Garis Regresi')
plt.title('Prediksi antara Tinggi badan Dan Point')
plt.xlabel('Tinggi Badan')
plt.ylabel('Banyak Point')
plt.legend()
plt.grid(True)
plt.show()
